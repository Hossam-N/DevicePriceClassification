# %%
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import joblib

# %%
data = pd.read_excel("./Data/train.xlsx")

# %%
data.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim    fc  four_g  int_memory  \
# 0            842     0          2.2         0   1.0     0.0         7.0
# 1           1021     1          0.5         1   0.0     1.0        53.0
# 2            563     1          0.5         1   2.0     1.0        41.0
# 3            615     1          2.5         0   0.0     0.0        10.0
# 4           1821     1          1.2         0  13.0     1.0        44.0
#
#    m_dep  mobile_wt  n_cores  ...  px_height  px_width     ram  sc_h  sc_w  \
# 0    0.6      188.0      2.0  ...       20.0     756.0  2549.0   9.0   7.0
# 1    0.7      136.0      3.0  ...      905.0    1988.0  2631.0  17.0   3.0
# 2    0.9      145.0      5.0  ...     1263.0    1716.0  2603.0  11.0   2.0
# 3    0.8      131.0      6.0  ...     1216.0    1786.0  2769.0  16.0   8.0
# 4    0.6      141.0      2.0  ...     1208.0    1212.0  1411.0   8.0   2.0
#
#    talk_time  three_g  touch_screen  wifi  price_range
# ...

# %%
data.info()
# all of the data is numerical, which will facilite its use and may not require some encoding
# number of null values is small
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             1995 non-null   float64
#  5   four_g         1995 non-null   float64
#  6   int_memory     1995 non-null   float64
#  7   m_dep          1995 non-null   float64
#  8   mobile_wt      1996 non-null   float64
#  9   n_cores        1996 non-null   float64
#  10  pc             1995 non-null   float64
#  11  px_height      1996 non-null   float64
#  12  px_width       1998 non-null   float64
#  13  ram            1998 non-null   float64
#  14  sc_h           1999 non-null   float64
#  15  sc_w           1999 non-null   float64
#  16  talk_time      2000 non-null   int64
# ...

# %%
data.isnull().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               5
# four_g           5
# int_memory       5
# m_dep            5
# mobile_wt        4
# n_cores          4
# pc               5
# px_height        4
# px_width         2
# ram              2
# sc_h             1
# sc_w             1
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
data.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  1995.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.310276
# std       439.418206     0.5001     0.816004     0.500035     4.335766
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  1995.000000  1995.000000  1995.000000  1996.000000  1996.000000  ...
# mean      0.521303    32.048120     0.502256   140.266533     4.518036  ...
# std       0.499671    18.146476     0.288530    35.384676     2.288946  ...
# ...

# %%
# Since number of null values is small compared to the size of data, we can safely drop them
data = data.dropna()

# %%
data.isnull().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
data.describe() 
# data insights before and after dropping null values are apporoximately the same
# Out:
#        battery_power         blue  clock_speed     dual_sim           fc  \
# count    1991.000000  1991.000000  1991.000000  1991.000000  1991.000000
# mean     1238.270718     0.496233     1.522451     0.510799     4.307885
# std       439.641057     0.500111     0.815499     0.500009     4.339735
# min       501.000000     0.000000     0.500000     0.000000     0.000000
# 25%       851.500000     0.000000     0.700000     0.000000     1.000000
# 50%      1225.000000     0.000000     1.500000     1.000000     3.000000
# 75%      1615.500000     1.000000     2.200000     1.000000     7.000000
# max      1998.000000     1.000000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  1991.000000  1991.000000  1991.000000  1991.000000  1991.000000  ...
# mean      0.520844    32.074335     0.502009   140.263184     4.516323  ...
# std       0.499691    18.138177     0.288622    35.398777     2.291257  ...
# ...

# %%
plt.figure(figsize=(10,6))
sns.histplot(data['battery_power'],bins = 10, color='blue')
plt.title('Histogram of battery_power before scaling')
plt.xlabel('battery_power')
plt.ylabel('frequency')
plt.grid(axis='y', alpha=0.75)
plt.show()

# %%
# Scaling the features for faster training convergence
scaler = MinMaxScaler()
data.iloc[:,:-1] = scaler.fit_transform(data.iloc[:,:-1])
data.head()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_6392\3735114867.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.22778891 0.34736139 0.04141617 ... 0.94188377 0.6753507  0.00601202]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.iloc[:,:-1] = scaler.fit_transform(data.iloc[:,:-1])
# C:\Users\user\AppData\Local\Temp\ipykernel_6392\3735114867.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.94444444 0.27777778 0.38888889 ... 0.16666667 0.94444444 0.        ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.iloc[:,:-1] = scaler.fit_transform(data.iloc[:,:-1])
#    battery_power  blue  clock_speed  dual_sim        fc  four_g  int_memory  \
# 0       0.227789     0         0.68         0  0.052632     0.0    0.080645
# ...

# %%
plt.figure(figsize=(10,6))
sns.histplot(data['battery_power'],bins = 10, color='blue')
plt.title('Histogram of battery_power after scaling')
plt.xlabel('battery_power')
plt.ylabel('frequency')
plt.grid(axis='y', alpha=0.75)
plt.show()

# battery_power range is from zero to one

# %%
data.describe()
# Out:
#        battery_power         blue  clock_speed     dual_sim           fc  \
# count    1991.000000  1991.000000   1991.00000  1991.000000  1991.000000
# mean        0.492499     0.496233      0.40898     0.510799     0.226731
# std         0.293681     0.500111      0.32620     0.500009     0.228407
# min         0.000000     0.000000      0.00000     0.000000     0.000000
# 25%         0.234135     0.000000      0.08000     0.000000     0.052632
# 50%         0.483634     0.000000      0.40000     1.000000     0.157895
# 75%         0.744489     1.000000      0.68000     1.000000     0.368421
# max         1.000000     1.000000      1.00000     1.000000     1.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  1991.000000  1991.000000  1991.000000  1991.000000  1991.000000  ...
# mean      0.520844     0.485070     0.446677     0.502193     0.502332  ...
# std       0.499691     0.292551     0.320691     0.294990     0.327322  ...
# ...

# %%
# checking count of each category target variable price_range to check for data imbalance
data.value_counts('price_range').plot(kind='bar')

# from observed output, dataset is balanced, therefor no need for data balancing techniques (oversampling, undersampling)
# Out:
# <Axes: xlabel='price_range'>

# %%
# saving scaler for later use
joblib.dump(scaler, 'Outputs/scaler.pkl')
# Out:
# ['Outputs/scaler.pkl']

# %%
# safe the cleaned data as excel file
data.to_excel('Data/cleaned_data.xlsx', index=False)
